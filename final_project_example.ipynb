# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset.
# Ensure the dataset file exists and is in the same directory as this jupyter notebook.
HMS_df = pd.read_csv('HMS_2023-2024_qv clean.csv')

# Display the first few rows of the dataframe to ensure it is loaded correctly
display(HMS_df.head())

#show columns and each column's data type
HMS_df.info() 
HMS_df.isnull().sum()

#usually you need to store this in a new variable
dropped_df = HMS_df.dropna()
dropped_df.isnull().sum()

display(dropped_df.head())
# Out:
# /var/folders/vv/51q1pwt94k78ll52rvgs9l3m0000gn/T/ipykernel_71799/2286788170.py:8: DtypeWarning: Columns (12,36,42,181,197,209,217,225,238,243,356,362,373,404,474,521,603,615) have mixed types. Specify dtype option on import or set low_memory=False.
#   HMS_df = pd.read_csv('HMS_2023-2024_qv clean.csv')
#      RecordedDate   age  sex_birth  gender_male  gender_female  gender_queer  \
# 0    12/5/23 8:17  18.0        1.0          NaN            1.0           NaN
# 1  11/16/23 17:37  18.0        1.0          NaN            1.0           NaN
# 2   9/24/23 18:53  18.0        2.0          1.0            NaN           NaN
# 3   11/21/23 7:17  20.0        1.0          NaN            1.0           NaN
# 4   11/21/23 7:57  21.0        2.0          1.0            NaN           NaN
#
#    gender_nonbin  gender_trans  gender_prefnoresp  gender_selfID  ...  \
# 0            NaN           NaN                NaN            NaN  ...
# ...

# %%
# Question 1: Does mental health wellness differ between race/ethnicity?
MHW_by_RaceEth = HMS_df.groupby('sex_birth')["anymhprob"].mean()
sns.barplot(MHW_by_RaceEth)
plt.title("Mental Health Wellness by Race/Ethnicity")
plt.xlabel("Race/Ethnicity")
plt.ylabel("Mental Health Wellness Count")
plt.show()
