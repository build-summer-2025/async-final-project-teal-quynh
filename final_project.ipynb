# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset.
# Ensure the dataset file exists and is in the same directory as this jupyter notebook.
HMS_df = pd.read_csv('HMS_2023-2024_qv RACE final.csv')

# Display the first few rows of the dataframe to ensure it is loaded correctly
display(HMS_df.head())

# Show columns and each column's data type
HMS_df.info() 
HMS_df.isnull().sum()
# Out:
#     age sex_birth ALL_GENDER       ALL_SEX         ALL_RACE  \
# 0  22.0    Female     Female  Heterosexual  Hispanic/Latino
# 1  19.0    Female     Female      Bisexual            White
# 2  20.0      Male      Queer  Heterosexual  Hispanic/Latino
# 3  24.0    Female        NaN  Heterosexual            White
# 4  19.0    Female     Female      Bisexual       Multi Race
#
#                             ALL_Degree ALL_GRADE belongStrongly agree  \
# 0                          Certificate       A's                Agree
# 1          Post-Baccalaureate Programs       A's       Strongly agree
# 2                           Bachelor's    A'sB's                Agree
# 3  12nd degree Middle School Education    C'sD's      Somewhat agree
# 4                          Certificate       A's                Agree
#
#      mh_prior_demo   aca_impa  ... dep_or_anx ed_scoff ed_any sib_any  \
# 0            Agree        NaN  ...         No      0.0    0.0     0.0
# ...

# %%
# Question 1: What’s the Demographic makeup of my data?
# Create new variable 'data_by_race' to store the dataset
data_by_race = pd.DataFrame(HMS_df)

# Get the count value for each variables
race_counts = data_by_race['ALL_RACE'].value_counts()
sexbirth_count = data_by_race['sex_birth'].value_counts()
GenID_count = data_by_race['ALL_GENDER'].value_counts()

# Graph pie chart for racial breakdown of my data
display(race_counts)
explode = [0,0,0,0,0,1,1,1]
race_counts.plot(kind='pie', title='Race Breakdown', autopct='%1.1f%%', pctdistance=1.2, labeldistance=None, explode=explode, fontsize=7)
plt.legend(bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.ylabel('')
plt.show()

# Graph pie chart for sex at birth breakdown of my data
sexbirth_count.plot(kind='pie', title='Sex at Birth Breakdown', autopct='%1.1f%%', pctdistance=1.2, labeldistance=None)
plt.legend(loc="best")
plt.ylabel('')
plt.show()

# Graph pie chart for gender identity breakdown of my data
GenID_count.plot(kind='pie', title='Gender Identities Breakdown', autopct='%1.1f%%', pctdistance=1.2, labeldistance=None)
plt.legend(bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.ylabel('')
plt.show()

### need help with the number percentage on race breakdown
# Out:
# ALL_RACE
# White                                19080
# Multi Race                            3177
# Asian American/Asian                  2560
# Hispanic/Latino                       2430
# African American/Black                2360
# Middle Eastern/Arab/Arab American      305
# American Indian/Alaskan Native         183
# Native Hawaiian/Pacific Islander        42
# Name: count, dtype: int64

# %%
# Question 2: Does financial status differ between racial groups for college students?
categories = ['Always stressful', 'Often stressful', 'Sometimes stressful', 'Rarely stressful', 'Never stressful']
data_by_race['fincur'] = pd.Categorical(data_by_race['fincur'], categories=categories, ordered=True)
freq_table_FC = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['fincur'])  
stacked_data_FC = freq_table_FC.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_FC.plot(kind="barh", stacked=True)
plt.title('Current Financial Stress by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.show()

data_by_race['finpast'] = pd.Categorical(data_by_race['finpast'], categories=categories, ordered=True)
freq_table_FP = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['finpast'])  
stacked_data_FP = freq_table_FP.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_FP.plot(kind="barh", stacked=True)
plt.title('Past Financial Stress by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.show()

###how to move the ordering around

# %%
# Question 3: Does substance use differ between racial groups?
freq_table_SU = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['sub_any'])  
stacked_data_SU = freq_table_SU.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_SU.plot(kind="barh", stacked=True)
plt.title('Substance Use by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

# %%
# Question 4: Does mental health wellbeing differ between racial groups?
freq_table_AMH = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['anymhprob'])  
stacked_data_AMH = freq_table_AMH.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_AMH.plot(kind="barh", stacked=True)
plt.title('Mental Health Wellbeing by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

freq_table_SUI = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['sui_idea'])  
stacked_data_SUI = freq_table_SUI.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_SUI.plot(kind="barh", stacked=True)
plt.title('Suicidal Ideation by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

freq_table_DPP = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['dep_any'])  
stacked_data_DPP = freq_table_DPP.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_DPP.plot(kind="barh", stacked=True)
plt.title('Depression by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

freq_table_ANX = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['anx_any'])  
stacked_data_ANX = freq_table_ANX.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_ANX.plot(kind="barh", stacked=True)
plt.title('Anxiety by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

# %%
# Question 5: Does mental state about academic performance differ between racial groups?
freq_table_MSA = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['aca_impa'])  
stacked_data_MSA = freq_table_MSA.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_MSA.plot(kind="barh", stacked=True)
plt.title('Mental State of Academic Performance by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()

# %%
# Question 6: Does current grades differ between racial groups?
freq_table_GPA = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['ALL_GRADE'])  
stacked_data_GPA = freq_table_GPA.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_GPA.plot(kind="barh", stacked=True)
plt.title('Current Academic Performance by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.show()

# %%
# Question 7: Does knowledge of mental health resources on campus differ between racial groups?
categories = ['Strongly agree', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Disagree', 'Strongly disagree']
data_by_race['knowwher'] = pd.Categorical(data_by_race['knowwher'], categories=categories, ordered=True)
freq_table_KMH = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['knowwher'])
stacked_data_KMH = freq_table_KMH.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_KMH.plot(kind="barh", stacked=True)
plt.title('Knowledge of Mental Health Resources on Campus by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.show()

# %%
# Question 8: Does mental health stigma differ between racial groups?
categories = ['Strongly agree ', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Disagree', 'Strongly disagree']
data_by_race['stig_pcv'] = pd.Categorical(data_by_race['stig_pcv'], categories=categories, ordered=True)
freq_table_Stigma = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['stig_pcv'])  
stacked_data_Stigma = freq_table_Stigma.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_Stigma.plot(kind="barh", stacked=True)
plt.title('Mental Health Stigma by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(1.0, 1.0),fontsize='small')
plt.show()

# %%
# Question 9: Does therapy usage differ between racial groups?
freq_table_TU = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['ther_ever'])  
stacked_data_TU = freq_table_TU.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_TU.plot(kind="barh", stacked=True)
plt.title('Therapy Usage by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Key Legend:',bbox_to_anchor=(0, 0),fontsize='small')
plt.show()

# %%
# Question 10: Does self-guided therapy usage differ between racial groups?
freq_table_SGTU = pd.crosstab(data_by_race['ALL_RACE'], data_by_race['ther_selfguide'])  
stacked_data_SGTU = freq_table_SGTU.apply(lambda x: x*100/sum(x), axis=1)
stacked_data_SGTU.plot(kind="barh", stacked=True)
plt.title('Self-Guided Therapy Usage by Race')
plt.xlabel('Percentage')
plt.ylabel('Race')
plt.xticks(rotation=0)
plt.legend(title='Answer')
plt.show()
